# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('medical_examination.csv')

df.head()
# Out:
#    id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393    2     168    62.0    110     80            1     1      0
# 1   1  20228    1     156    85.0    140     90            3     1      0
# 2   2  18857    1     165    64.0    130     70            3     1      0
# 3   3  17623    2     169    82.0    150    100            1     1      0
# 4   4  17474    1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
#Manera en la que la hice Yo
bmi=df['weight']/(df['height']/100)**2
bmi=bmi.tolist()
bmif=list()
for i in bmi:
    if i > 25 :
        #print('hola')
        bmif.append(1)
    else:
        bmif.append(0)
        
bmif=pd.Series(bmif)   
df['overweight']=bmif
df.head()
#MANERA EN QUE CHATGPT OPTIMIZO EL CODIGO

# Supongamos que ya tienes un DataFrame llamado df con las columnas 'weight' y 'height'.

# Calcula el BMI para todo el DataFrame directamente.
#df['bmi'] = df['weight'] / (df['height'] / 100) ** 2

# Crea la columna 'overweight' utilizando una función lambda y apply.
#df['overweight'] = df['bmi'].apply(lambda x: 1 if x > 25 else 0)
#df=df.drop(columns='bmi')
#df.head()
#Ahora, desglosemos cada componente del código:
#1.df['bmi'].apply(...): Esto toma la columna 'bmi' del DataFrame 'df' y aplica una función a cada elemento de esa columna.

#2.lambda x: 1 if x > 25 else 0: Aquí estamos definiendo una función lambda que toma un argumento x (que será cada valor de la columna 'bmi' en este caso) y devuelve 1 si x es mayor que 25 y 0 en caso contrario.

#3. La función lambda se aplica a cada valor en la columna 'bmi'. Para cada valor x, la función lambda determina si es mayor que 25 o no. Si es mayor que 25, se devuelve 1; de lo contrario, se devuelve 0.

#4.Los valores devueltos por la función lambda se asignan a la columna 'overweight' del DataFrame 'df'
# Out:
#    id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393    2     168    62.0    110     80            1     1      0
# 1   1  20228    1     156    85.0    140     90            3     1      0
# 2   2  18857    1     165    64.0    130     70            3     1      0
# 3   3  17623    2     169    82.0    150    100            1     1      0
# 4   4  17474    1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio  overweight
# 0     0       1       0           0
# 1     0       1       1           1
# 2     0       0       1           0
# 3     0       1       1           1
# 4     0       0       0           0

# %%
for index, row in df.iterrows():
    if index==10:
        break
    else:
        print(row['cholesterol']==1)

    #else:
        #print(df.loc[index,'cholesterol'])
# Out:
# True
# False
# False
# True
# True
# False
# False
# False
# True
# True

# %%
# Out:
#    id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393    2     168    62.0    110     80            0     0      0
# 1   1  20228    1     156    85.0    140     90            1     0      0
# 2   2  18857    1     165    64.0    130     70            1     0      0
# 3   3  17623    2     169    82.0    150    100            0     0      0
# 4   4  17474    1     156    56.0    100     60            0     0      0
#
#    alco  active  cardio  overweight
# 0     0       1       0           0
# 1     0       1       1           1
# 2     0       0       1           0
# 3     0       1       1           1
# 4     0       0       0           0

# %%
for index, row in df.iterrows():
    if row['cholesterol']==1:
        #print('bobo',index)
        df.loc[index, 'cholesterol']=0
    else:
        #print('tonto',index)
        df.loc[index, 'cholesterol'] =1
for index, row in df.iterrows():
    if row['gluc']==1:
        #print('bobo',index)
        df.loc[index, 'gluc']=0
    else:
        #print('tonto',index)
        df.loc[index, 'gluc'] =1
df.head()
#for index, row in df.iterrows():: Este es un bucle for que itera a través de las filas de un DataFrame llamado df. 
#En cada iteración, index contiene el índice de la fila y row contiene los datos de esa fila como una serie pandas.
#MANERA EN QUE CHATGPT OPTIMIZO EL CODIGO
#df['cholesterol'] = df['cholesterol'].apply(lambda x: 0 if x == 1 else 1)
#df['gluc'] = df['gluc'].apply(lambda x: 0 if x == 1 else 1)
#df.head()
#Ver amterior slide para encontar como funciona apply y lambda
# Out:
#    id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393    2     168    62.0    110     80            0     0      0
# 1   1  20228    1     156    85.0    140     90            1     0      0
# 2   2  18857    1     165    64.0    130     70            1     0      0
# 3   3  17623    2     169    82.0    150    100            0     0      0
# 4   4  17474    1     156    56.0    100     60            0     0      0
#
#    alco  active  cardio  overweight
# 0     0       1       0           0
# 1     0       1       1           1
# 2     0       0       1           0
# 3     0       1       1           1
# 4     0       0       0           0

# %%
#Aca estaba normalizando la columna overweight con los valores de cholesterol y glucosa, etendi mal las instrucciones
#count=0
#for (i,j) in zip(df['cholesterol'],df['gluc']):
#    print(i,j)
#    if i==1 or j == 1:
#        #print('entro en 1')
#        df.loc[count,'overweight']=0
#       print(count)
#   elif i > 1 or j > 1:
#        #print('entro en 2')
#        df.loc[count,'overweight']=1
#    else:
#        print('jeje')
#    count=count + 1 
#mejor manera de hacerlo:
#for index, row in df.iterrows():
#    if row['cholesterol'] == 1 or row['gluc'] == 1:
#        df.loc[index, 'overweight'] = 0
#    elif row['cholesterol'] > 1 or row['gluc'] > 1:
#        df.loc[index, 'overweight'] = 1
#    else:
#        pass

# %%
df_melt=df.melt(id_vars=['cardio'],value_vars=['active','alco','cholesterol','gluc','overweight','smoke'])
df_melt.sample(10)
#id_vars=['cardio']: Este argumento especifica las columnas que se mantendrán como identificadores (variables clave) en el DataFrame resultante. En este caso, solo se mantiene la columna 'cardio' como un identificador.
#value_vars=['active', 'alco', 'cholesterol', 'gluc', 'overweight', 'smoke']): Este argumento especifica las columnas que se "desenrollarán" o "derretirán" en una sola columna. Estas columnas se convertirán en valores dentro de esa columna. 
# En este caso, las columnas 'active', 'alco', 'cholesterol', 'gluc', 'overweight' y 'smoke' se desenrollarán en una sola columna.
# Out:
#         cardio     variable  value
# 194158       1  cholesterol      0
# 15173        1       active      1
# 247770       0         gluc      1
# 162477       0  cholesterol      0
# 107768       0         alco      0
# 387106       1        smoke      1
# 396502       0        smoke      0
# 115727       1         alco      0
# 289034       0   overweight      0
# 28320        1       active      1

# %%
sns.catplot(x='variable',kind='count',data=df_melt,hue='value',col='cardio')
#sns.catplot(: Esto indica que se está utilizando la función catplot de la biblioteca Seaborn para crear un gráfico categórico.

#x='variable': Aquí se especifica que la variable que se representará en el eje x del gráfico es la columna 'variable' del DataFrame.
#kind='count': Este argumento indica que el tipo de gráfico que se creará es un gráfico de conteo. En otras palabras, el gráfico mostrará cuántas veces aparece cada valor en la columna 'variable'.
#data=df_melt: Aquí se especifica el DataFrame que se utilizará para crear el gráfico, en este caso, es el DataFrame df_melt.
#hue='value': Este argumento indica que se usará la columna 'value' para diferenciar los datos en el gráfico. En otras palabras, el gráfico mostrará diferentes colores o tonos para representar los diferentes valores en la columna 'value'.
#col='cardio': Este argumento indica que se creará una columna de gráficos separados para cada valor único en la columna 'cardio'. En este caso, habrá dos columnas de gráficos, una para 'cardio' igual a 0 y otra para 'cardio' igual a 1.

# %%
df.head()
# Out:
#    id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393    2     168    62.0    110     80            0     0      0
# 1   1  20228    1     156    85.0    140     90            1     0      0
# 2   2  18857    1     165    64.0    130     70            1     0      0
# 3   3  17623    2     169    82.0    150    100            0     0      0
# 4   4  17474    1     156    56.0    100     60            0     0      0
#
#    alco  active  cardio  overweight
# 0     0       1       0           0
# 1     0       1       1           1
# 2     0       0       1           0
# 3     0       1       1           1
# 4     0       0       0           0

# %%
df=df[df['height'] >= df['height'].quantile(0.025)]
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69996  99995  22601    1     158   126.0    140     90            1     1
# 69997  99996  19066    2     183   105.0    180     90            1     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  overweight
# 0          0     0       1       0           0
# 1          0     0       1       1           1
# 2          0     0       0       1           0
# 3          0     0       1       1           1
# 4          0     0       0       0           0
# ...      ...   ...     ...     ...         ...
# 69995      1     0       1       0           1
# 69996      0     0       1       1           1
# 69997      0     1       0       1           1
# 69998      0     0       0       1           1
# 69999      0     0       1       0           0
#
# [67260 rows x 14 columns]

# %%
df=df[df['weight'] >= df['weight'].quantile(0.025)]
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69996  99995  22601    1     158   126.0    140     90            1     1
# 69997  99996  19066    2     183   105.0    180     90            1     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  overweight
# 0          0     0       1       0           0
# 1          0     0       1       1           1
# 2          0     0       0       1           0
# 3          0     0       1       1           1
# 4          0     0       0       0           0
# ...      ...   ...     ...     ...         ...
# 69995      1     0       1       0           1
# 69996      0     0       1       1           1
# 69997      0     1       0       1           1
# 69998      0     0       0       1           1
# 69999      0     0       1       0           0
#
# [65783 rows x 14 columns]

# %%
df=df[df['weight'].quantile(0.975) >= df['weight']]
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69994  99992  21074    1     165    80.0    150     80            0     0
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69997  99996  19066    2     183   105.0    180     90            1     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  overweight
# 0          0     0       1       0           0
# 1          0     0       1       1           1
# 2          0     0       0       1           0
# 3          0     0       1       1           1
# 4          0     0       0       0           0
# ...      ...   ...     ...     ...         ...
# 69994      0     0       1       1           1
# 69995      1     0       1       0           1
# 69997      0     1       0       1           1
# 69998      0     0       0       1           1
# 69999      0     0       1       0           0
#
# [64254 rows x 14 columns]

# %%
df=df[df['height'].quantile(0.975) >= df['height']]
#df_cleaned=[df[df['height']<=df['height'].quantile(0.975)]] POR ALGUNA RAZON ASI NO SIRVE, O SE DAÑA EL DATAFRAME
#El código que proporcionaste filtra el DataFrame df, manteniendo solo las filas donde la altura (height) sea menor o igual al valor del percentil 97.5 de la columna de altura.

# %%
#Todos JUNTOS
df = df[
    (df['ap_lo'] <= df['ap_hi']) &
    (df['height'] >= df['height'].quantile(0.025)) &
    (df['height'] <= df['height'].quantile(0.975)) &
    (df['weight'] >= df['weight'].quantile(0.025)) &
    (df['weight'] <= df['weight'].quantile(0.975))
]
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69993  99991  19699    1     172    70.0    130     90            0     0
# 69994  99992  21074    1     165    80.0    150     80            0     0
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  overweight
# 0          0     0       1       0           0
# 1          0     0       1       1           1
# 2          0     0       0       1           0
# 3          0     0       1       1           1
# 4          0     0       0       0           0
# ...      ...   ...     ...     ...         ...
# 69993      0     0       1       1           0
# 69994      0     0       1       1           1
# 69995      1     0       1       0           1
# 69998      0     0       0       1           1
# 69999      0     0       1       0           0
#
# [63020 rows x 14 columns]

# %%
correlation_matrix=df.corr()
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
plt.figure(figsize=(12,8))
sns.heatmap(correlation_matrix,mask=mask,annot=True,fmt='.1f')
plt.title('Matriz de Dorrelacion')
#correlation_matrix contiene la matriz de correlación calculada a partir de tu DataFrame df.
#sns.heatmap() se utiliza para crear un gráfico de calor que representa visualmente la matriz de correlación. El argumento annot=True agrega valores numéricos a las celdas del mapa de calor. El argumento cmap se utiliza para especificar una paleta de colores, y fmt=".2f" se utiliza para formatear los valores con dos decimales.
#plt.title() se utiliza para agregar un título al gráfico de calor.
# Out:
# Text(0.5, 1.0, 'Matriz de Dorrelacion')
